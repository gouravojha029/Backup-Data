# %%
# tupl

# %%
t1=(1,2,3,4,5)

# %%
type(t1)
# Out:
# tuple

# %%
t1=()

# %%
type(t1)
# Out:
# tuple

# %%
t1=(10)   # not a tuple

# %%
type(t1)
# Out:
# int

# %%
t1=(10,)

# %%
type(t1)
# Out:
# tuple

# %%
t4=10,20,30

# %%
type(t4)
# Out:
# tuple

# %%
t3=1,2,3,4,5,6

# %%
type(t3)
# Out:
# tuple

# %%
# since indexing is there so we can use while loop for accessing each element

# %%
t1=(10,20,30,40)

# %%
i=0
while i<len(t1):
    print(t1[i])
i=i+1
# Out:
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# ...

# %%
i=0
while i<len(t1):
    print(t1[i])
    i=i+1
# Out:
# 10
# 20
# 30
# 40

# %%
# concatenation and repetition operator

# %%
t1=(10,20)
t2=(11,22,33)

# %%
t1+t2
# Out:
# (10, 20, 11, 22, 33)

# %%
t1*2
# Out:
# (10, 20, 10, 20)

# %%
# comparision operator  it works same as list

# %%
t1=(10,20)
t2=(11,33,55)

# %%
t1>t2
# Out:
# False

# %%
t1==t2
# Out:
# False

# %%
# tuple object method(attributes)

# %%
# since it is immutable so funct such as (clear,remove,inssert,append,etc )
# cannot be appliacble to it.

# %%
# index() and count() is only attributes of tuple

# %%
# since list comprehension type is not available here therefore type conversion
# can be done.

# %%
t1=tuple([int(i) for i in input("enter a number separated by comma").split(',')])
# Out:
# enter a number separated by comma10,20,30,40,50,60,70

# %%
t1
# Out:
# (10, 20, 30, 40, 50, 60, 70)
